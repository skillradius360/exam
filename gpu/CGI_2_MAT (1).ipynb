# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 10000)
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %%
nps= np.arange(1,10)
npr =np.linspace(1,15,9)
print(nps)
plotted = plt.plot(nps,npr);
plt.title("straight line")
plt.xlabel("X-->")
# Out:
# [1 2 3 4 5 6 7 8 9]
# Text(0.5, 0, 'X-->')

# %%
a1= np.array([[1,2,11],[41,11,62]])
a2= np.array([[1,22,8],[4,14,40]])
plt.scatter(a1,a2)
plt.title("scattered")
# Out:
# Text(0.5, 1.0, 'scattered')

# %%
np.random.seed(2)
print(np.random.randint(1,10))
# Out:
# 9

# %%
pies = np.array([20,60,44,5])
plt.pie(pies);

# %%
bar_points = np.arange(5);
plt.bar(np.array(["A","B","c","D","E"]),bar_points)
# Out:
# <BarContainer object of 5 artists>
